# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Uh4FyaAU1EVvux91YQzf")
project = rf.workspace("xray-u9rf3").project("crane_person_jib")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crane_person_jib-2 in yolov8:: 100%|██████████| 17620/17620 [00:02<00:00, 6911.89it/s]

# %%
# !pip install ultralytics

# %%
# Read the updated text file
with open('/kaggle/working/crane_person_jib-1/data.yaml', 'r') as file:
    updated_content = file.read()

# Display the updated content
print(updated_content)
# Out:
# names:
# - crane-hook
# - person
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: crane_person_jib
#   url: https://universe.roboflow.com/xray-u9rf3/crane_person_jib/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test:
# train: /kaggle/working/crane_person_jib-1/train
# val: /kaggle/working/crane_person_jib-1/valid

# %%
# %%writefile /kaggle/working/crane_person_jib-1/data.yaml
# names:
# - crane-hook
# - person
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: crane_person_jib
#   url: https://universe.roboflow.com/xray-u9rf3/crane_person_jib/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test:
# train: /kaggle/working/crane_person_jib-1/train
# val: /kaggle/working/crane_person_jib-1/valid
# Out:
# Overwriting /kaggle/working/crane_person_jib-1/data.yaml

# %%
# Read the updated text file
with open('/kaggle/working/crane_person_jib-1/data.yaml', 'r') as file:
    updated_content = file.read()

# Display the updated content
print(updated_content)
# Out:
# names:
# - crane-hook
# - person
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: crane_person_jib
#   url: https://universe.roboflow.com/xray-u9rf3/crane_person_jib/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test:
# train: /kaggle/working/crane_person_jib-1/train
# val: /kaggle/working/crane_person_jib-1/valid

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data="/kaggle/working/crane_person_jib-1/data.yaml", epochs=10000, imgsz=640, device=[0, 1], patience=25,  batch=32, workers=10)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 278MB/s]
# Ultralytics 8.3.94 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data="/kaggle/working/crane-1/data.yaml", epochs=10000, imgsz=640, device=[0, 1], patience=25,  batch=32, workers=10)

# %%
import shutil
import os
from IPython.display import FileLink, display, HTML

def zip_folder(input_folder_path):
    # Define the name for the zip file
    zip_file_path = input_folder_path + '.zip'
    
    # Zip the folder
    shutil.make_archive(input_folder_path, 'zip', input_folder_path)
    
    # Check if the zip file is created successfully
    if os.path.exists(zip_file_path):
        print(f"Folder zipped successfully at: {zip_file_path}")
    else:
        print("Error in zipping the folder.")
    
    return zip_file_path

def create_download_link(zip_file_path):
    # Create a download link for the zip file
    display(HTML(f'<a href="{zip_file_path}" download>Click here to download {zip_file_path}</a>'))
    
    # JavaScript to automatically trigger the download
    display(HTML(f"""
        <script>
        var link = document.createElement('a');
        link.href = '{zip_file_path}';
        link.download = '{os.path.basename(zip_file_path)}';
        document.body.appendChild(link);
        link.click();
        document.body.removeChild(link);
        </script>
    """))

# Example usage
input_folder_path = '/kaggle/working/runs/detect/train'  # Replace with your folder path
zip_file_path = zip_folder(input_folder_path)

# Automatically trigger the download
create_download_link(zip_file_path)
# Out:
# Folder zipped successfully at: /kaggle/working/runs/detect/train.zip
# <a href="/kaggle/working/runs/detect/train.zip" download>Click here to download /kaggle/working/runs/detect/train.zip</a>
#         <script>
#         var link = document.createElement('a');
#         link.href = '/kaggle/working/runs/detect/train.zip';
#         link.download = 'train.zip';
#         document.body.appendChild(link);
#         link.click();
#         document.body.removeChild(link);
#         </script>
